# %%
# !pip install selenium

# %%
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver = webdriver.Chrome(r'C:\Users\prasad kalekar\Selenium\chromedriver.exe')

# %%
driver.maximize_window()

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
url = 'https://www.naukri.com/'
driver.get(url)

# %%
search_job = driver.find_element(By.CLASS_NAME,"suggestor-input ")
search_job.send_keys('Data Scientist')

# %%
search_locn = driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
search_locn.send_keys('Bangalore')

# %%
search_btn = driver.find_element(By.CLASS_NAME,'qsbSubmit')
search_btn.click()

# %%
job_titles = []
title_tags = driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags:
    job_titles.append(i.text)
len(job_titles)
# Out:
# 20

# %%
job_titles
# Out:
# ['Analystics & Modeling Specialist',
#  'Senior Data Scientist',
#  'Data Scientist - Looking For Immediate Joiners',
#  'Assistant Manager - Data Science',
#  'Data Scientist',
#  'Data Scientist',
#  'ACN - Applied Intelligence - Data Scientist - 09',
#  'Data Scientist - 2',
#  'Data Scientist',
#  'Assistant Vice President - Data Scientist - KPO',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist - II',
#  'Lead ML Scientist',
#  'Python Programming Language Data Science Practitioner',
#  'Industry X - Software Engineering',
#  'Data Scientist: Artificial Intelligence',
#  'ACN - Applied Intelligence - C4DI - Sustainability - 09',
#  'Data Scientist',
#  'Data Scientist']

# %%
company_names = []
company_tags = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags:
    company_names.append(i.text)
len(company_names)
# Out:
# 20

# %%
company_names
# Out:
# ['Accenture',
#  'Wipro',
#  'Wipro',
#  'Citiustech',
#  'Altair',
#  'Quest Global',
#  'Accenture',
#  '24 7 ai',
#  'HCLTech',
#  'Huquo Consulting Pvt. Ltd',
#  'Infinics Global Solutions Pvt Ltd',
#  'Boston Consulting Group',
#  'Bizongo',
#  'Fractal Analytics',
#  'Accenture',
#  'Accenture',
#  'IBM',
#  'Accenture',
#  'Applied Materials',
#  'Applied Materials']

# %%
job_skills = []
skills = driver.find_elements(By.XPATH,'//ul[@class="tags has-description"]')
for i in skills:
    job_skills.append(i.text)
len(job_skills)
# Out:
# 20

# %%
job_skills
# Out:
# ['Bfsi\nConsulting\nMachine learning\nOpen source\nPython\nIT Skills\nBusiness process\nMarket research',
#  'RapidMiner\nFlask\nRabbit MQ\nNumPy\nDeep Learning\nApache Kafka\nLSTM\nPandas',
#  'Data Science\nPredictive Modeling\nRecommendation Engine\nTime Series\nPython\nPredictive Analysis\nSAS\nanalytical',
#  'Data Science\nNLP\nMachine Learning\nDeep Learning\nPython\nR\nData Modelling\nAnalytical',
#  'Python\nData Science\nJava\nMLOps\nNLP\nData Scientist\nData Modeling\nR Program',
#  'Data Scientist\nAzure\nproduct deployment\nAI\nML\nSQL\nPython',
#  'Computer science\nAutomation\nMachine learning\nMonitoring\nPython\nlearning\nIT Skills\nData Science',
#  'Natural Language Processing\nJava\nSQL queries\npresentation\nPython\nSpeech Recognition\nJavaScript\nNatural Language',
#  'pytorch\nIT Skills\nData Science\nMachine Learning\ndeep learning\ntensorflow\nnlp\nreinforcement learning',
#  'R\nSQL\nPython\nJava\nC++\ndata visualization techniques\nScala\nHadoop',
# ...

# %%
jobs = pd.DataFrame()
jobs['Job Title'] = job_titles
jobs['Company'] = company_names
jobs['Skills'] = job_skills
jobs
# Out:
#                                             Job Title  \
# 0                    Analystics & Modeling Specialist
# 1                               Senior Data Scientist
# 2      Data Scientist - Looking For Immediate Joiners
# 3                    Assistant Manager - Data Science
# 4                                      Data Scientist
# 5                                      Data Scientist
# 6    ACN - Applied Intelligence - Data Scientist - 09
# 7                                  Data Scientist - 2
# 8                                      Data Scientist
# 9     Assistant Vice President - Data Scientist - KPO
# 10                                     Data Scientist
# 11                              Senior Data Scientist
# 12                                Data Scientist - II
# 13                                  Lead ML Scientist
# 14  Python Programming Language Data Science Pract...
# 15                  Industry X - Software Engineering
# ...

# %%
driver = webdriver.Chrome(r'C:\Users\prasad kalekar\Selenium\chromedriver.exe')

# %%
driver.maximize_window()

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
url = 'https://www.naukri.com/'
driver.get(url)

# %%
search_job = driver.find_element(By.CLASS_NAME,"suggestor-input ")
search_job.send_keys('Data Analyst')

# %%
search_locn = driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
search_locn.send_keys('Bangalore')

# %%
search_btn = driver.find_element(By.CLASS_NAME,'qsbSubmit')
search_btn.click()

# %%
job_titles = []
title_tags = driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags:
    job_titles.append(i.text)
len(job_titles)
# Out:
# 20

# %%
job_titles
# Out:
# ['Senior Data Analyst - PLM Data Migration',
#  'Lead Data Analyst',
#  'Sr. Data Analyst (SAS Data Management)',
#  'Data Analyst',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Sr Data Analyst',
#  'Senior Analyst - Data Management',
#  'Data Analyst - Python/Artificial Intelligence',
#  'CONSULTANT - DATA ANALYST - CRM ERP',
#  'Data Analyst',
#  'Contractual Hiring For Top MNC || Business Data Analyst || Bangalore',
#  'Master Data Management Business Analyst',
#  'Lead Data Analyst(SQL, Python)',
#  'Data Analyst',
#  'Data Analyst',
#  'Lead Data Analyst',
#  'HR Data Analyst',
#  'Data and Analytics Analyst',
#  'Data Analyst 2']

# %%
company_names = []
company_tags = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags:
    company_names.append(i.text)
len(company_names)
# Out:
# 20

# %%
company_names
# Out:
# ['CGI',
#  'Mobile Premier League (MPL)',
#  'NMS Consultant',
#  'IBM',
#  'IBM',
#  'Groundtruth',
#  'Mettox Laboratries',
#  'Accenture',
#  'iMindYourBusiness',
#  'Pratham Books',
#  'Phonepe',
#  'TeamLease',
#  'Accenture',
#  'Cimpress',
#  'Bsharp',
#  'Qualitest',
#  'SVB Global Services India Llp',
#  'Hitachi Ltd.',
#  'IBM',
#  'Zynga']

# %%
job_skills = []
skills = driver.find_elements(By.XPATH,'//ul[@class="tags has-description"]')
for i in skills:
    job_skills.append(i.text)
len(job_skills)
# Out:
# 20

# %%
job_skills
# Out:
# ['PLM\nData migration\nTest scripts\nCGI\nPackaging\nPLM Data migration\nServiceNow\nTeamcenter',
#  'Marketing analytics\nGoogle Analytics\nMachine learning\nHypothesis Testing\nData analytics\nPredictive analytics\nAWS\nSQL',
#  'SAS VI\ndata management\nbase sas\nSAS DI\npostgree\nSAS SQL\ndata analytics\ndata analysis',
#  'SAP\nAnalytical\nMS Office\nMacros\nData extraction\nTrend analysis\nTroubleshooting',
#  'SAP\nAnalytical\nMS Office\nMacros\nData extraction\nFinance\nTrend analysis\nTroubleshooting',
#  'Analytics\nPython\nSQL\nCritical Thinking\ndata analysis\nExcel\nAWS',
#  'Data analysis\ntableau\nProcess improvement\nConsulting\npower bi\ndata integrity\nData Analyst\nManagement',
#  'Publishing\nData management\nAnalytical\nArtificial Intelligence\nConsulting\nIT Skills\nCloud\nBig Data',
#  'Python\nVBA\nC++\nSQL server\nAdvanced Excel\nIT Skills\nData Science\nArtificial Intelligence',
# ...

# %%
job = pd.DataFrame()
job['Job Title'] = job_titles
job['Company'] = company_names
job['Skills'] = job_skills
job
# Out:
#                                             Job Title  \
# 0            Senior Data Analyst - PLM Data Migration
# 1                                   Lead Data Analyst
# 2              Sr. Data Analyst (SAS Data Management)
# 3                                        Data Analyst
# 4                                        Data Analyst
# 5                                 Senior Data Analyst
# 6                                     Sr Data Analyst
# 7                    Senior Analyst - Data Management
# 8       Data Analyst - Python/Artificial Intelligence
# 9                 CONSULTANT - DATA ANALYST - CRM ERP
# 10                                       Data Analyst
# 11  Contractual Hiring For Top MNC || Business Dat...
# 12            Master Data Management Business Analyst
# 13                     Lead Data Analyst(SQL, Python)
# 14                                       Data Analyst
# 15                                       Data Analyst
# ...

# %%
driver = webdriver.Chrome(r'C:\Users\prasad kalekar\Selenium\chromedriver.exe')

# %%
driver.maximize_window()

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
url = 'https://www.naukri.com/'
driver.get(url)

# %%
search_job = driver.find_element(By.CLASS_NAME,"suggestor-input ")
search_job.send_keys('Data Scientist')

# %%
search_locn = driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
search_locn.send_keys('Delhi')

# %%
search_btn = driver.find_element(By.CLASS_NAME,'qsbSubmit')
search_btn.click()

# %%
job_titles = []
title_tags = driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags:
    job_titles.append(i.text)
job_titles
# Out:
# ['Data Scientist',
#  'Senior Data Scientist',
#  'Opportunity For Data Scientist - Female Candidates ONLY',
#  'AVAP Agile Information Systems - Data Scientist - Machine Learning',
#  'Data Scientist',
#  'Data Scientist',
#  'DigitalBCG GAMMA Data Scientist',
#  'Data Scientist',
#  'Senior Analyst-Data Science',
#  'ACN - Applied Intelligence - Data & Insights - CSS - 09',
#  'Data Scientist: Advanced Analytics',
#  'Assistant Vice President - Data Scientist - KPO',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist / Senior ML Engineer',
#  'ACN - Applied Intelligence - CC - Data Science (IN) - 09',
#  'Sr Data Scientist | Gurgaon | WFO',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist']

# %%
company_names = []
company_tags = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags:
    company_names.append(i.text)
company_names
# Out:
# ['HCLTech',
#  'Boston Consulting Group',
#  'PayU Finance',
#  'AVAP Agile',
#  'ACS Solutions',
#  'ACS Solutions',
#  'Boston Consulting Group',
#  'Siemens',
#  'Accenture',
#  'Accenture',
#  'IBM',
#  'Huquo Consulting Pvt. Ltd',
#  'Infinics Global Solutions Pvt Ltd',
#  'Junglee Games',
#  'Indigo Airlines',
#  'Accenture',
#  'Ofb Tech',
#  'TRH Consultancy Services',
#  'TRH Consultancy Services',
#  'TRH Consultancy Services']

# %%
job_skills = []
skills = driver.find_elements(By.XPATH,'//ul[@class="tags has-description"]')
for i in skills:
    job_skills.append(i.text)
job_skills
# Out:
# ['pytorch\nIT Skills\nData Science\nMachine Learning\ndeep learning\ntensorflow\nnlp\nreinforcement learning',
#  'Supply chain\nadvanced analytics\nDue diligence\nNetwork analysis\nConsulting\nManagement consulting\nMachine learning\nPredictive modeling',
#  'python\nNoSQL\nmodel development\nModel Building\nDeep Learning\nData Science\nspark\nDjango',
#  'Machine Learning\nIT Skills\nPython\nC++\nLinux\nData science\nPerl',
#  'machine learning\npython\ndata science\nsql',
#  'machine learning\nData science\ncommunication\nPython\nJupyter\nScrum\nSQL databases\nLean',
#  'Supply chain\nComputer science\nadvanced analytics\nArtificial Intelligence\nNetwork analysis\nMachine learning\nManagement consulting\nPredictive modeling',
#  'Data analysis\nCoding\nAnalytical\nSignal processing\nData mining\nMATLAB\nCivil engineering\nSQL',
#  'Publishing\nArtificial Intelligence\nConsulting\nMachine learning\nAnalytics\nIT Skills\nData Science\nCloud',
# ...

# %%
job_locn = []
locn = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft fs12 lh16 locWdth"]')
for i in locn:
    job_locn.append(i.text)
job_locn
# Out:
# ['Noida, Hyderabad/Secunderabad, Chennai, Bangalore/Bengaluru',
#  'New Delhi, Mumbai, Chennai, Bangalore/Bengaluru',
#  'Hybrid - Gurgaon/Gurugram, Bangalore/Bengaluru, Mumbai (All Areas)',
#  'Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secunderabad, Pune, Chennai, Ahmedabad, Bangalore/Bengaluru',
#  'Noida, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru',
#  'Noida, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru',
#  'New Delhi, Bangalore/Bengaluru',
#  'Gurgaon/Gurugram',
#  'Gurgaon/Gurugram',
#  'Gurgaon/Gurugram',
#  'Gurgaon/Gurugram',
#  'Delhi / NCR, Mumbai, Hyderabad/Secunderabad, Pune, Gurgaon/Gurugram, Chennai, Bangalore/Bengaluru',
#  'Delhi / NCR, Kolkata, Hyderabad/Secunderabad, Pune, Ahmedabad, Chennai, Bangalore/Bengaluru, Mumbai (All Areas)',
#  'Gurgaon/Gurugram',
#  'Gurgaon/Gurugram',
#  'Gurgaon/Gurugram',
#  'Gurgaon/Gurugram',
#  'Kolkata, Mumbai, Nagpur, Hyderabad/Secunderabad, Pune, Chennai, Coimbatore, Bangalore/Bengaluru, Delhi',
# ...

# %%
job_d = pd.DataFrame()
job_d['Job Title'] = job_titles
job_d['Company'] = company_names
job_d['Skills'] = job_skills
job_d['Location'] = job_locn
job_d
# Out:
#                                             Job Title  \
# 0                                      Data Scientist
# 1                               Senior Data Scientist
# 2   Opportunity For Data Scientist - Female Candid...
# 3   AVAP Agile Information Systems - Data Scientis...
# 4                                      Data Scientist
# 5                                      Data Scientist
# 6                     DigitalBCG GAMMA Data Scientist
# 7                                      Data Scientist
# 8                         Senior Analyst-Data Science
# 9   ACN - Applied Intelligence - Data & Insights -...
# 10                 Data Scientist: Advanced Analytics
# 11    Assistant Vice President - Data Scientist - KPO
# 12                                     Data Scientist
# 13                              Senior Data Scientist
# 14         Senior Data Scientist / Senior ML Engineer
# 15  ACN - Applied Intelligence - CC - Data Science...
# ...

# %%
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver = webdriver.Chrome(r'C:\Users\prasad kalekar\Selenium\chromedriver.exe')

# %%
driver.maximize_window()
driver = webdriver.Chrome('chromedriver.exe')

# %%
url = ' https://www.flipkart.com/'

driver.get(url)

# %%
search_item = driver.find_element(By.CLASS_NAME,"_3704LK")
search_item.send_keys('Sunglasses')

# %%
search_btn = driver.find_element(By.CLASS_NAME,'L0Z3Pu')
search_btn.click()

# %%
brand_name = []
brand = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand:
    brand_name.append(i.text)
brand_name
# Out:
# ['RESIST EYEWEAR',
#  'Resist',
#  'Fastrack',
#  'PIRASO',
#  'VINCENT CHASE',
#  'Fastrack',
#  'Fastrack',
#  'ARICKS',
#  'SUNBEE',
#  'New Specs',
#  'ROYAL SON',
#  'ARICKS',
#  'PIRASO',
#  'Fastrack',
#  'PIRASO',
#  'Sewell',
#  'ROZZETTA CRAFT',
#  'ROYAL SON',
#  'VINCENT CHASE',
#  'Fastrack',
#  'ROZZETTA CRAFT',
#  'Singco India',
#  'PIRASO',
#  'GANSTA',
#  'PIRASO',
#  'GANSTA',
#  'PROVOGUE',
#  'ROZZETTA CRAFT',
#  'Elligator',
#  'Fastrack',
#  'ROZZETTA CRAFT',
#  'SUNBEE',
#  'Elligator',
#  'Fastrack',
#  'CRYSTAL CART',
#  'ROZZETTA CRAFT',
#  'Silver Kartz',
#  'ROYAL SON',
#  'PIRASO',
#  'SHAAH COLLECTIONS']

# %%
prd_des = []
des = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in des:
    prd_des.append(i.text)
prd_des
# Out:
# ['Polarized, Riding Glasses, UV Protection Wayfarer Sungl...',
#  'Toughened Glass Lens, UV Protection, Riding Glasses, Ph...',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Rectangular Sunglasses (52)',
#  'UV Protection Wayfarer Sunglasses (59)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Shield Sunglasses (Free Size)',
#  'UV Protection, Polarized Rectangular Sunglasses (Free S...',
#  'UV Protection, Polarized Wayfarer Sunglasses (Free Size...',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Retro Square Sunglasses (60)',
#  'UV Protection, Polarized Rectangular Sunglasses (Free S...',
#  'UV Protection Aviator Sunglasses (54)',
#  'Gradient, UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (55)',
#  'Mirrored, Night Vision, UV Protection, Riding Glasses S...',
#  'UV Protection Aviator Sunglasses (55)',
#  'UV Protection, Polarized Round Sunglasses (54)',
# ...

# %%
len(prd_des)
# Out:
# 40

# %%
prd_price = []
price = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price:
    prd_price.append(i.text)
prd_price
# Out:
# ['₹1,399',
#  '₹1,399',
#  '₹649',
#  '₹199',
#  '₹649',
#  '₹519',
#  '₹649',
#  '₹236',
#  '₹283',
#  '₹254',
#  '₹569',
#  '₹259',
#  '₹251',
#  '₹579',
#  '₹251',
#  '₹265',
#  '₹616',
#  '₹699',
#  '₹949',
#  '₹679',
#  '₹426',
#  '₹215',
#  '₹251',
#  '₹220',
#  '₹209',
#  '₹296',
#  '₹664',
#  '₹379',
#  '₹197',
#  '₹629',
#  '₹379',
#  '₹190',
#  '₹176',
#  '₹579',
#  '₹189',
#  '₹474',
#  '₹288',
#  '₹664',
#  '₹323',
#  '₹185']

# %%
flip = pd.DataFrame()
flip['Brand'] = brand_name
flip['Description'] = prd_des

flip['Price'] = prd_price
flip
# Out:
#                 Brand                                        Description  \
# 0      RESIST EYEWEAR  Polarized, Riding Glasses, UV Protection Wayfa...
# 1              Resist  Toughened Glass Lens, UV Protection, Riding Gl...
# 2            Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 3              PIRASO          UV Protection Rectangular Sunglasses (52)
# 4       VINCENT CHASE             UV Protection Wayfarer Sunglasses (59)
# 5            Fastrack   UV Protection Rectangular Sunglasses (Free Size)
# 6            Fastrack        UV Protection Shield Sunglasses (Free Size)
# 7              ARICKS  UV Protection, Polarized Rectangular Sunglasse...
# 8              SUNBEE  UV Protection, Polarized Wayfarer Sunglasses (...
# 9           New Specs   UV Protection Rectangular Sunglasses (Free Size)
# 10          ROYAL SON         UV Protection Retro Square Sunglasses (60)
# 11             ARICKS  UV Protection, Polarized Rectangular Sunglasse...
# ...

# %%
driver = webdriver.Chrome(r'C:\Users\prasad kalekar\Selenium\chromedriver.exe')
driver.maximize_window()
driver = webdriver.Chrome('chromedriver.exe')
url = ' https://www.flipkart.com/'

driver.get(url)

# %%
search_item = driver.find_element(By.CLASS_NAME,"_3704LK")
search_item.send_keys('Sneakers')

# %%
search_btn = driver.find_element(By.CLASS_NAME,'L0Z3Pu')
search_btn.click()

# %%
brand_name = []
brand = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand:
    brand_name.append(i.text)
brand_name
# Out:
# ['RapidBox',
#  'Rzisbo',
#  'RED TAPE',
#  'RED TAPE',
#  'Labbin',
#  'PUMA',
#  'TR',
#  'Kraasa',
#  'Kraasa',
#  'SCATCHITE',
#  'T-ROCK',
#  'Layasa',
#  'ASTEROID',
#  'BRUTON',
#  'Robbie jones',
#  'RapidBox',
#  'KNIGHT WALKERS',
#  'KNIGHT WALKERS',
#  'TR',
#  'Deals4you',
#  'HONEY',
#  'Elevarse',
#  'Magnolia',
#  'PUMA',
#  'BRUTON',
#  'aadi',
#  'Shozie',
#  'gargcreation',
#  'BRUTON',
#  'ASTEROID',
#  'Kraasa',
#  'GFUND',
#  'Sparx',
#  'World Wear Footwear',
#  'BRUTON',
#  'Robbie jones',
#  'GFUND',
#  'HRX by Hrithik Roshan',
#  'AMICO',
#  'BRUTON']

# %%
prd_price = []
price = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price:
    prd_price.append(i.text)
prd_price
# Out:
# ['₹549',
#  '₹449',
#  '₹1,249',
#  '₹1,079',
#  '₹395',
#  '₹2,020',
#  '₹299',
#  '₹499',
#  '₹499',
#  '₹360',
#  '₹395',
#  '₹449',
#  '₹499',
#  '₹389',
#  '₹329',
#  '₹599',
#  '₹749',
#  '₹749',
#  '₹299',
#  '₹389',
#  '₹449',
#  '₹299',
#  '₹299',
#  '₹1,966',
#  '₹179',
#  '₹499',
#  '₹549',
#  '₹299',
#  '₹324',
#  '₹499',
#  '₹499',
#  '₹449',
#  '₹873',
#  '₹249',
#  '₹199',
#  '₹349',
#  '₹449',
#  '₹1,805',
#  '₹494',
#  '₹574']

# %%
flip = pd.DataFrame()
flip['Brand'] = brand_name
flip['Price'] = prd_price
flip
# Out:
#                     Brand   Price
# 0                RapidBox    ₹549
# 1                  Rzisbo    ₹449
# 2                RED TAPE  ₹1,249
# 3                RED TAPE  ₹1,079
# 4                  Labbin    ₹395
# 5                    PUMA  ₹2,020
# 6                      TR    ₹299
# 7                  Kraasa    ₹499
# 8                  Kraasa    ₹499
# 9               SCATCHITE    ₹360
# 10                 T-ROCK    ₹395
# 11                 Layasa    ₹449
# 12               ASTEROID    ₹499
# 13                 BRUTON    ₹389
# 14           Robbie jones    ₹329
# 15               RapidBox    ₹599
# 16         KNIGHT WALKERS    ₹749
# 17         KNIGHT WALKERS    ₹749
# 18                     TR    ₹299
# 19              Deals4you    ₹389
# 20                  HONEY    ₹449
# 21               Elevarse    ₹299
# 22               Magnolia    ₹299
# 23                   PUMA  ₹1,966
# 24                 BRUTON    ₹179
# 25                   aadi    ₹499
# ...

# %%
driver = webdriver.Chrome(r'C:\Users\prasad kalekar\Selenium\chromedriver.exe')
driver.maximize_window()
driver = webdriver.Chrome('chromedriver.exe')
url = 'https://www.myntra.com/shoes'

driver.get(url)

# %%
brand_name = []
brand = driver.find_elements(By.XPATH,'//h3[@class="product-brand"]')
for i in brand:
    brand_name.append(i.text)
brand_name
# Out:
# ['U.S. Polo Assn.',
#  'Roadster',
#  'Mast & Harbour',
#  'HIGHLANDER',
#  'Red Tape',
#  'U.S. Polo Assn.',
#  'Nike',
#  'Provogue',
#  'Roadster',
#  'Eego Italy',
#  'Red Tape',
#  'Campus',
#  'Skechers',
#  'El Paso',
#  'El Paso',
#  'Mactree',
#  'U.S. Polo Assn.',
#  'El Paso',
#  'Red Tape',
#  'Provogue',
#  'Nike',
#  'H&M',
#  'ADIDAS',
#  'Champs',
#  'HRX by Hrithik Roshan',
#  'Roadster',
#  'Nike',
#  'Khadims',
#  'Shoetopia',
#  'ASIAN',
#  'Mactree',
#  'U.S. Polo Assn.',
#  'Red Tape',
#  'Killer',
#  'Roadster',
#  'Red Tape',
#  'Zyla',
#  'Mactree',
#  'Provogue',
#  'Campus',
#  'AfroJack',
#  'U.S. Polo Assn.',
#  'ARIVO',
#  'HRX by Hrithik Roshan',
#  'H&M',
#  'Red Tape',
#  'El Paso',
#  'Nike',
#  'ADIDAS',
#  'HIGHLANDER']

# %%
prd_des = []
des = driver.find_elements(By.XPATH,'//h4[@class="product-product"]')
for i in des:
    prd_des.append(i.text)
prd_des
# Out:
# ['Men Clarkin Sneakers',
#  'Men Sneakers',
#  'Men Striped Sneakers',
#  'Men Sneakers',
#  'Men Walking Shoes',
#  'Men Colourblocked Sneakers',
#  'Men Zoom Winflo 8 Run Shoes',
#  'Men Colourblocked Sneakers',
#  'Men Sneakers',
#  'Men Trekking Shoes',
#  'Women Sneakers',
#  'Men Walking Sports Shoes',
#  'Women GO RUN FAST Shoes',
#  'Women Flat Boots',
#  'Women Flat Boots',
#  'Men Colourblocked PU Sneakers',
#  'Men Slip-On Sneakers',
#  'Women Solid Heeled Boots',
#  "Men's Running Shoes",
#  'Men Black Solid Formal Debys',
#  'Men AIR MAX 270 Sneakers',
#  'Woman Chelsea boots',
#  'Women Vertago Running Shoes',
#  'Men Mesh Running Shoes',
#  'Men Running Shoes',
#  'Men Textured Sneakers',
#  'Men AIR WINFLO 9 Running Shoes',
#  'Men Solid Loafers',
#  'Girls Colourblocked Trekking Shoes',
#  'Women Slip-On Sneakers',
#  'Men Colourblocked PU Sneakers',
#  'Men MADRYN 2.O Sneakers',
#  'Men Leather Biker Boots',
#  'Men Slip-On Sneakers',
# ...

# %%
prd_price = []
price = driver.find_elements(By.XPATH,'//div[@class="product-price"]')
for i in price:
    prd_price.append(i.text)
prd_price
# Out:
# ['Rs. 1649Rs. 2999(45% OFF)',
#  'Rs. 872Rs. 3795(77% OFF)',
#  'Rs. 944Rs. 2699(65% OFF)',
#  'Rs. 975Rs. 1990(51% OFF)',
#  'Rs. 1511Rs. 5599(73% OFF)',
#  'Rs. 1649Rs. 2999(45% OFF)',
#  'Rs. 6221Rs. 8295(25% OFF)',
#  'Rs. 799Rs. 3995(80% OFF)',
#  'Rs. 872Rs. 3795(77% OFF)',
#  'Rs. 987Rs. 2599(62% OFF)',
#  'Rs. 1295Rs. 4799(73% OFF)',
#  'Rs. 799Rs. 999(20% OFF)',
#  'Rs. 4399Rs. 5499(20% OFF)',
#  'Rs. 1082Rs. 4330(75% OFF)',
#  'Rs. 1082Rs. 4330(75% OFF)',
#  'Rs. 778Rs. 3890(80% OFF)',
#  'Rs. 979Rs. 2799( 65 % OFF)',
#  'Rs. 1082Rs. 4330(75% OFF)',
#  'Rs. 1376Rs. 5099(73% OFF)',
#  'Rs. 879Rs. 4495(Rs. 3616 OFF)',
#  'Rs. 12595Rs. 13995(10% OFF)',
#  'Rs. 2699',
#  'Rs. 1799Rs. 2999(40% OFF)',
#  'Rs. 1899',
#  'Rs. 1839Rs. 4599(60% OFF)',
#  'Rs. 943Rs. 4495(79% OFF)',
#  'Rs. 7645Rs. 8495(10% OFF)',
#  'Rs. 1399',
#  'Rs. 899Rs. 1999(55% OFF)',
#  'Rs. 447Rs. 699(36% OFF)',
#  'Rs. 798Rs. 4200(81% OFF)',
#  'Rs. 2209Rs. 3399(35% OFF)',
#  'Rs. 2051Rs. 7599(73% OFF)',
# ...

# %%
myntra = pd.DataFrame()
myntra['Brand'] = brand_name
myntra['Description'] = prd_des

myntra['Price'] = prd_price
myntra
# Out:
#                     Brand                         Description  \
# 0         U.S. Polo Assn.                Men Clarkin Sneakers
# 1                Roadster                        Men Sneakers
# 2          Mast & Harbour                Men Striped Sneakers
# 3              HIGHLANDER                        Men Sneakers
# 4                Red Tape                   Men Walking Shoes
# 5         U.S. Polo Assn.          Men Colourblocked Sneakers
# 6                    Nike         Men Zoom Winflo 8 Run Shoes
# 7                Provogue          Men Colourblocked Sneakers
# 8                Roadster                        Men Sneakers
# 9              Eego Italy                  Men Trekking Shoes
# 10               Red Tape                      Women Sneakers
# 11                 Campus            Men Walking Sports Shoes
# 12               Skechers             Women GO RUN FAST Shoes
# 13                El Paso                    Women Flat Boots
# ...

# %%
driver = webdriver.Chrome(r'C:\Users\prasad kalekar\Selenium\chromedriver.exe')
driver.maximize_window()
driver = webdriver.Chrome('chromedriver.exe')
url = 'https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART'

driver.get(url)

# %%
prd_rating = []
rating = driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in rating:
    prd_rating.append(i.text)
prd_rating
# Out:
# ['5', '4', '5', '5', '5', '5', '5', '5', '5', '5']

# %%
prd_r_summery = []
summary = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in summary:
    prd_r_summery.append(i.text)
prd_r_summery
# Out:
# ['Simply awesome',
#  'Value-for-money',
#  'Perfect product!',
#  'Best in the market!',
#  'Highly recommended',
#  'Worth every penny',
#  'Highly recommended',
#  'Perfect product!',
#  'Great product',
#  'Fabulous!']

# %%
prd_review = []
review = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
for i in review:
    prd_review.append(i.text)
prd_review
# Out:
# ['Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.',
#  "I'm Really happy with the product\nDelivery was fast as well\n..it was a gift for my sister and she loved it so much.",
#  'Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .',
#  'Great iPhone very snappy experience as apple kind. Upgraded from iPhone 7.\nPros\n-Camera top class\n- Battery top performed\n-Chipset no need to say as apple kind\n-Security as you expect from apple\n- Display super bright industry leading colour\naccuracy and super responsive\n-Build quality as expect from apple sturdy\npremium durable beautiful stylish.\n-Os most stable os in smartphone industry\n\nCons\n-No 5G\n-Display is not based on OLED technology\n-Charger headphones and 1 apple stic...\nREAD MORE',
# ...

# %%
iphone = pd.DataFrame()
iphone['Ratings'] = prd_rating
iphone['Review Summary'] = prd_r_summery

iphone['FullReview'] = prd_review
iphone
# Out:
#   Ratings       Review Summary  \
# 0       5       Simply awesome
# 1       4      Value-for-money
# 2       5     Perfect product!
# 3       5  Best in the market!
# 4       5   Highly recommended
# 5       5    Worth every penny
# 6       5   Highly recommended
# 7       5     Perfect product!
# 8       5        Great product
# 9       5            Fabulous!
#
#                                           FullReview
# 0  Really satisfied with the Product I received.....
# 1  I'm Really happy with the product\nDelivery wa...
# 2  Amazing phone with great cameras and better ba...
# 3  Great iPhone very snappy experience as apple k...
# 4  It's my first time to use iOS phone and I am l...
# 5  Previously I was using one plus 3t it was a gr...
# 6  What a camera .....just awesome ..you can feel...
# 7  Value for money\n5 star rating\nExcellent came...
# 8  Amazing Powerful and Durable Gadget.\n\nI’m am...
# 9  This is my first iOS phone. I am very happy wi...

# %%
driver = webdriver.Chrome(r'C:\Users\prasad kalekar\Selenium\chromedriver.exe')
driver.maximize_window()
driver = webdriver.Chrome('chromedriver.exe')
url = ' https://www.azquotes.com/'

driver.get(url)

# %%
Quote = []
q = driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in q:
    Quote.append(i.text)
Quote
# Out:
# ['The essence of strategy is choosing what not to do.',
#  'One cannot and must not try to erase the past merely because it does not fit the present.',
#  'Patriotism means to stand by the country. It does not mean to stand by the president.',
#  'Death is something inevitable. When a man has done what he considers to be his duty to his people and his country, he can rest in peace. I believe I have made that effort and that is, therefore, why I will sleep for the eternity.',
#  'You have to love a nation that celebrates its independence every July 4, not with a parade of guns, tanks, and soldiers who file by the White House in a show of strength and muscle, but with family picnics where kids throw Frisbees, the potato salad gets iffy, and the flies die from happiness. You may think you have overeaten, but it is patriotism.',
# ...

# %%
author = []
A = driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in A:
    author.append(i.text)
author
# Out:
# ['Michael Porter',
#  'Golda Meir',
#  'Theodore Roosevelt',
#  'Nelson Mandela',
#  'Erma Bombeck',
#  'John Wooden',
#  'Albert Einstein',
#  'Frank Zappa',
#  'William Faulkner',
#  'Will Rogers',
#  'Jimmy Carter',
#  'Albert Einstein',
#  'Abraham Lincoln',
#  'Steven Weinberg',
#  'Franklin D. Roosevelt',
#  'Albert Einstein',
#  'Maya Angelou',
#  'Mark Twain',
#  'Theodore Roosevelt',
#  'Michael Jackson',
#  'Martin Luther King, Jr.',
#  'C. S. Lewis',
#  'Theodore Roosevelt',
#  'Mark Twain',
#  'Abraham Lincoln',
#  'Ruth Graham',
#  'C. S. Lewis',
#  'Groucho Marx',
#  'John Lennon',
#  'Barbara Bush',
#  'Albert Einstein',
#  'Francis Chan',
#  'Henry Ford',
#  'Victor Hugo',
#  'Abu Bakr',
#  'Zig Ziglar',
#  'Winston Churchill',
#  'Zig Ziglar',
#  'John F. Kennedy',
#  'Dwight D. Eisenhower',
#  'Winston Churchill',
#  'Albert Einstein',
#  'Willie Nelson',
#  'Johnny Cash',
#  'Marie Curie',
#  'Maya Angelou',
#  'Amy Bloom',
#  'Zig Ziglar',
#  'John Lennon',
# ...

# %%
type_of_quote = []
A = driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in A:
    type_of_quote.append(i.text)
type_of_quote
# Out:
# ['Essence, Deep Thought, Transcendentalism',
#  'Inspiration, Past, Trying',
#  'Country, Peace, War',
#  'Inspirational, Motivational, Death',
#  '4th Of July, Food, Patriotic',
#  'Inspirational, Success, Basketball',
#  'Strong, Revenge, Intelligent',
#  'Inspirational, Teacher, Religious',
#  'Truth, Honesty, Lying',
#  'Funny, Reading, Learning',
#  'Strong, Thoughtful, Compassion',
#  'Love, Funny, Life',
#  'Freedom, Men, Democracies Have',
#  'God, Religious, Atheist',
#  'Respect, Kindness, Character',
#  'Inspirational, Motivational, Change',
#  'Inspirational, Life, Inspiring',
#  'Love, Inspirational, Life',
#  'Inspiring, Country, 4th Of July',
#  'Inspirational, Dream, Hate',
#  'Love, Inspirational, Life',
#  'Forgiveness, God, Christian',
#  'Country, Men, Squares',
#  'Inspirational, Relationship, Positive',
#  'Inspirational, Motivational, Positive',
#  'Love, Friendship, Relationship',
#  'Faith, God, Christian',
#  'Art, Freedom, Political Will',
# ...

# %%
df = pd.DataFrame()
df['Quote'] = Quote
df['Author'] = author

df['Type of Quote'] = type_of_quote
df
# Out:
#                                                 Quote                Author  \
# 0   The essence of strategy is choosing what not t...        Michael Porter
# 1   One cannot and must not try to erase the past ...            Golda Meir
# 2   Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3   Death is something inevitable. When a man has ...        Nelson Mandela
# 4   You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                ...                   ...
# 95     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 96  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 97  God doesn't require us to succeed, he only req...         Mother Teresa
# 98  If you think you are too small to make a diffe...            Dalai Lama
# 99    Change your thoughts and you change your world.  Norman Vincent Peale
#
#                                Type of Quote
# ...

# %%
driver = webdriver.Chrome(r'C:\Users\prasad kalekar\Selenium\chromedriver.exe')
driver.maximize_window()
driver = webdriver.Chrome('chromedriver.exe')
url =   'https://www.motor1.com/'

driver.get(url)

# %%
car = []
c = driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in c:
    car.append(i.text)
car
# Out:
# ['Drako GTE',
#  'De Tomaso P72',
#  'Ferrari LaFerrari',
#  'Pagani Huayra',
#  'McLaren Elva',
#  'Czinger 21C',
#  'Ferrari Monza',
#  'Gordon Murray T.33',
#  'Koenigsegg Gemera',
#  'Zenvo TSR-S',
#  'Hennessey Venom F5',
#  'Bentley Bacalar',
#  'Hispano Suiza Carmen Boulogne',
#  'Bentley Mulliner Batur',
#  'Deus Vayanne',
#  'SSC Tuatara',
#  'Lotus Evija',
#  'Aston Martin Vulcan',
#  'Delage D12',
#  'McLaren Speedtail',
#  'Rimac Nevera',
#  'Pagani Utopia',
#  'Pininfarina Battista',
#  'Ferrari FXX K Evo',
#  'Gordon Murray T.50',
#  'Lamborghini Countach',
#  'Mercedes-AMG Project One',
#  'Aston Martin Victor',
#  'Hennessey Venom F5 Roadster',
#  'Koenigsegg Jesko',
#  'Aston Martin Valkyrie',
#  'W Motors Lykan Hypersport',
#  'McLaren Solus',
#  'Pagani Huayra Roadster BC',
#  'Bugatti Chiron Pur Sport',
#  'Lamborghini Sian',
#  'Koenigsegg CC850',
#  'Bugatti Chiron Super Sport 300+',
#  'Lamborghini Veneno',
#  'Bugatti Bolide',
#  'Bugatti Mistral',
# ...

# %%
df = pd.DataFrame()
df['Top Cars'] = car
df
# Out:
#                             Top Cars
# 0                          Drako GTE
# 1                      De Tomaso P72
# 2                  Ferrari LaFerrari
# 3                      Pagani Huayra
# 4                       McLaren Elva
# 5                        Czinger 21C
# 6                      Ferrari Monza
# 7                 Gordon Murray T.33
# 8                  Koenigsegg Gemera
# 9                        Zenvo TSR-S
# 10                Hennessey Venom F5
# 11                   Bentley Bacalar
# 12     Hispano Suiza Carmen Boulogne
# 13            Bentley Mulliner Batur
# 14                      Deus Vayanne
# 15                       SSC Tuatara
# 16                       Lotus Evija
# 17               Aston Martin Vulcan
# 18                        Delage D12
# 19                 McLaren Speedtail
# 20                      Rimac Nevera
# 21                     Pagani Utopia
# 22              Pininfarina Battista
# 23                 Ferrari FXX K Evo
# ...
